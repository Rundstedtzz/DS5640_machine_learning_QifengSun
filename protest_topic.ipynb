# %% [markdown]
# <a href="https://colab.research.google.com/github/Rundstedtzz/DS5640_machine_learning_QifengSun/blob/main/protest_topic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/ACLED"
# Out:
# /content/drive/MyDrive/ACLED

# %%
import pandas as pd
import numpy as np
import json 
import ast

# %%
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 94.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 108.2 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
protest = pd.read_csv('ACLED_protests-riots_1-26.csv')

# %% [markdown]
# # Model

# %%
# !pip install sentencepiece
# import sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.6 MB/s eta 0:00:00
# ...

# %%
classifier = pipeline("zero-shot-classification",
                      model="joeddav/xlm-roberta-large-xnli")
# Out:
# ...
# Some weights of the model checkpoint at joeddav/xlm-roberta-large-xnli were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
topic = []
labels = ["LGBT", "human rights", "education", "race", "workers rights", "health care", "environment"]

# %%
pd.set_option('display.max_columns', None)
protest.head(1)
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0  9790398   24       ANG3791              3791  20 January 2023  2023
#
#    time_precision event_type    sub_event_type               actor1  \
# 0               1   Protests  Peaceful protest  Protesters (Angola)
#
#              assoc_actor_1  inter1 actor2 assoc_actor_2  inter2  interaction  \
# 0  Street Traders (Angola)       6    NaN           NaN       0           60
#
#           region country  admin1    admin2  admin3 location  latitude  \
# 0  Middle Africa  Angola  Cunene  Cuanhama  Onjiva  Ondjiva  -17.0666
#
#    longitude  geo_precision               source source_scale  \
# 0    15.7333              1  Angola Press Agency     National
#
#                                                notes  fatalities   timestamp  \
# 0  On 20 January 2023, vendors demonstrated at Os...           0  1674487330
#
#   iso3
# 0  AGO

# %%
protest_subset = protest.loc[protest['country'].isin(["United States"]) & (protest['event_type'] == "Protests")]
# protest_subset = protest.loc[protest['country'] == 'Sweden'| protest['country'] == 'South Korea']
# protest_subset = protest.query('country == Sweden & country == South Korea')

# %%
protest_subset

# %%
protest_subset1 = protest_subset.copy()[24506:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-595a1851ccb3> in <module>
# ----> 1 protest_subset1 = protest_subset.copy()[25661:]
#
# NameError: name 'protest_subset' is not defined

# %%
protest_subset1
# Out:
#         data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 329356  7615723  840      USA22216             22216  24 January 2021  2021
# 329357  7615778  840      USA22271             22271  24 January 2021  2021
# 329358  7615780  840      USA22273             22273  24 January 2021  2021
# 329359  7615811  840      USA22304             22304  24 January 2021  2021
# 329360  7615813  840      USA22306             22306  24 January 2021  2021
# ...         ...  ...           ...               ...              ...   ...
# 496161  7616930  840      USA23636             23636  01 January 2020  2020
# 496162  7617409  840      USA23414             23414  01 January 2020  2020
# 496163  7617578  840      USA23635             23635  01 January 2020  2020
# 496173  8265777  840      USA23488             23488  01 January 2020  2020
# 496174  8265778  840      USA23726             23726  01 January 2020  2020
#
# ...

# %%
topic[4123]
# Out:
# {'sequence': "On 6 August 2022, a group of protesters gathered in downtown El Paso (Texas) to protest against Operation Lone Star, the border security operation instituted by Governor Greg Abbott. This event was called the 'Day of Action to condemn Op Lone Star.' The organizers of the events were several organizations advocating for the rights of Latinx immigrants, including Border Network for Human Rights, Frontera Texas, Arise Adelante, Proyecto Libertad, Movimiento del Valle, Border Workers United, and La Union del Pueblo Entero (which also advocates for workers' rights). [size=no report]",
#  'labels': ['workers rights',
#   'human rights',
#   'race',
#   'LGBT',
#   'environment',
#   'health care',
#   'education'],
#  'scores': [0.5266518592834473,
#   0.371132493019104,
#   0.033476073294878006,
#   0.02808964066207409,
#   0.01646539755165577,
#   0.014460849575698376,
#   0.009723673574626446]}

# %%
topic1 = []

# %%
for i in range(len(protest_subset1)):
  result = classifier(protest_subset1["notes"].tolist()[i], labels, multi_label=False)
  topic1.append(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-037a452dd6ea> in <module>
#       1 for i in range(len(protest_subset1)):
# ----> 2   result = classifier(protest_subset1["notes"].tolist()[i], labels, multi_label=False)
#       3   topic1.append(result)
#
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/zero_shot_classification.py in __call__(self, sequences, *args, **kwargs)
#     203             raise ValueError(f"Unable to understand extra arguments {args}")
#     204
# --> 205         return super().__call__(sequences, **kwargs)
#     206
#     207     def preprocess(self, inputs, candidate_labels=None, hypothesis_template="This example is {}."):
#
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
# ...

# %%
for i in range(len(protest_subset)):
  result = classifier(protest_subset["notes"].tolist()[i], labels, multi_label=False)
  topic.append(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-4857fb79f095> in <module>
#       1 for i in range(len(protest_subset)):
# ----> 2   result = classifier(protest_subset["notes"].tolist()[i], labels, multi_label=False)
#       3   topic.append(result)
#
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/zero_shot_classification.py in __call__(self, sequences, *args, **kwargs)
#     203             raise ValueError(f"Unable to understand extra arguments {args}")
#     204
# --> 205         return super().__call__(sequences, **kwargs)
#     206
#     207     def preprocess(self, inputs, candidate_labels=None, hypothesis_template="This example is {}."):
#
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
# ...

# %%
topic
# Out:
# []

# %%
topic.extend(topic1)

# %%
protest_subset[45219:]['notes']
# Out:
# 472431    On 2 March 2020, about 30 Trump supporters hel...
# 472437    On 2 March 2020, Iowans gathered for Iowa Pray...
# 472447    On 2 March 2020, more than 100 graduate studen...
# 472448    On 2 March 2020, about 30 demonstrators in Los...
# 472455    On 2 March 2020, about 30 parents, students an...
#                                 ...
# 496161    On 1 January 2020, a group of people gathered ...
# 496162    On 1 January 2020, protesters gathered at NYPD...
# 496163    On 1 January 2020, a group of people gathered ...
# 496173    On 1 January 2020, protesters assembled along ...
# 496174    On 1 January 2020, protesters against Oklahoma...
# Name: notes, Length: 1831, dtype: object

# %%
len(topic1)
# Out:
# 1155

# %%
protest_subset[41971:]['notes']
# Out:
# 446283    On 2 June 2020, hundreds of protesters attende...
# 446299    On 2 June 2020, about 200 protesters assembled...
# 446316    On 2 June 2020, over 100 people staged a prote...
# 446317    On 2 June 2020, about 200 people staged a prot...
# 446319    On 2 June 2020, a crowd protested in Little Ro...
#                                 ...
# 496161    On 1 January 2020, a group of people gathered ...
# 496162    On 1 January 2020, protesters gathered at NYPD...
# 496163    On 1 January 2020, a group of people gathered ...
# 496173    On 1 January 2020, protesters assembled along ...
# 496174    On 1 January 2020, protesters against Oklahoma...
# Name: notes, Length: 5079, dtype: object

# %%
from collections import Counter

counter = Counter(map(type, topic))
print(counter)
# Out:
# Counter({<class 'dict'>: 32668, <class 'list'>: 1})

# %%
result = classifier(protest_subset["notes"].tolist()[i], labels, multi_label=False)
# Out:
# dict

# %%
index, item = next((i, x) for i, x in enumerate(topic) if type(x) == list)
print(f'The list item is at index {index}')
# Out:
# The list item is at index 4594

# %%
current_progress = pd.DataFrame(topic)

# %%
temp = pd.DataFrame(topic1)

# %%
current_progress
# Out:
#                                                 sequence  \
# 0      On 20 January 2023, demonstrators gathered at ...
# 1      On 20 January 2023, hundreds of people rallied...
# 2      On 20 January 2023, Maximus call center worker...
# 3      On 20 January 2023, an unreported number of pe...
# 4      On 20 January 2023, demonstrators gathered in ...
# ...                                                  ...
# 51570  On 1 January 2020, a group of people gathered ...
# 51571  On 1 January 2020, protesters gathered at NYPD...
# 51572  On 1 January 2020, a group of people gathered ...
# 51573  On 1 January 2020, protesters assembled along ...
# 51574  On 1 January 2020, protesters against Oklahoma...
#
#                                                   labels  \
# 0      [human rights, race, environment, education, w...
# 1      [human rights, education, health care, race, L...
# 2      [workers rights, human rights, race, environme...
# ...

# %%
temp.to_csv("temp.csv")

# %%
current_progress.to_csv("us_topic.csv")

# %%
us = current_progress.drop(index=35050)

# %%
us
# Out:
#                                                 sequence  \
# 0      On 20 January 2023, demonstrators gathered at ...
# 1      On 20 January 2023, hundreds of people rallied...
# 2      On 20 January 2023, Maximus call center worker...
# 3      On 20 January 2023, an unreported number of pe...
# 4      On 20 January 2023, demonstrators gathered in ...
# ...                                                  ...
# 47046  On 1 January 2020, a group of people gathered ...
# 47047  On 1 January 2020, protesters gathered at NYPD...
# 47048  On 1 January 2020, a group of people gathered ...
# 47049  On 1 January 2020, protesters assembled along ...
# 47050  On 1 January 2020, protesters against Oklahoma...
#
#                                                   labels  \
# 0      [environment, race, human rights, workers righ...
# 1      [environment, race, human rights, LGBT, educat...
# 2      [workers rights, race, human rights, environme...
# ...

# %%
us.to_csv("environment_us.csv")

# %%
current_progress.drop_duplicates(subset=['sequence'])

# %%
protest_subset
# Out:
#         data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 231     9798576  840      USA51390             51390  20 January 2023  2023
# 232     9798585  840      USA51399             51399  20 January 2023  2023
# 233     9798587  840      USA51401             51401  20 January 2023  2023
# 234     9798594  840      USA51408             51408  20 January 2023  2023
# 235     9798598  840      USA51412             51412  20 January 2023  2023
# ...         ...  ...           ...               ...              ...   ...
# 496161  7616930  840      USA23636             23636  01 January 2020  2020
# 496162  7617409  840      USA23414             23414  01 January 2020  2020
# 496163  7617578  840      USA23635             23635  01 January 2020  2020
# 496173  8265777  840      USA23488             23488  01 January 2020  2020
# 496174  8265778  840      USA23726             23726  01 January 2020  2020
#
#         time_precision event_type    sub_event_type  \
# ...

# %%
topic[35050]
# Out:
# {'sequence': 'On 12 July 2020, people gathered in protest in San Angelo (Texas) to pay homage to Vanessa Guillen, a Latin soldier who was missing since April 22. Protesters were calling for justice after it was revealed she was sexually harassed and killed by another Fort Hood soldier, hoping to shed light on her story. [size=no report]',
#  'labels': ['race',
#   'human rights',
#   'environment',
#   'education',
#   'LGBT',
#   'workers rights',
#   'health care'],
#  'scores': [0.2713850140571594,
#   0.26705145835876465,
#   0.15624141693115234,
#   0.08796461671590805,
#   0.0820053368806839,
#   0.08142231404781342,
#   0.053929854184389114]}

# %%
protest_subset[35050:]['notes']
# Out:
# 422472    On 12 July 2020, people gathered in protest in...
# 422473    On 12 July 2020, people held a silent protest ...
# 422474    On 12 July 2020, people rallied and marched in...
# 422475    On 12 July 2020, around 30 people staged a pro...
# 422476    On 12 July 2020, people marched in Bowling Gre...
#                                 ...
# 496161    On 1 January 2020, a group of people gathered ...
# 496162    On 1 January 2020, protesters gathered at NYPD...
# 496163    On 1 January 2020, a group of people gathered ...
# 496173    On 1 January 2020, protesters assembled along ...
# 496174    On 1 January 2020, protesters against Oklahoma...
# Name: notes, Length: 12000, dtype: object

# %%
us[35050:]['sequence']
# Out:
# 35051    On 12 July 2020, people gathered in protest in...
# 35052    On 12 July 2020, people held a silent protest ...
# 35053    On 12 July 2020, people rallied and marched in...
# 35054    On 12 July 2020, around 30 people staged a pro...
# 35055    On 12 July 2020, people marched in Bowling Gre...
#                                ...
# 47046    On 1 January 2020, a group of people gathered ...
# 47047    On 1 January 2020, protesters gathered at NYPD...
# 47048    On 1 January 2020, a group of people gathered ...
# 47049    On 1 January 2020, protesters assembled along ...
# 47050    On 1 January 2020, protesters against Oklahoma...
# Name: sequence, Length: 12000, dtype: object
