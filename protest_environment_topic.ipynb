# %% [markdown]
# <a href="https://colab.research.google.com/github/Rundstedtzz/DS5640_machine_learning_QifengSun/blob/main/protest_environment_topic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/ACLED"
# Out:
# /content/drive/MyDrive/ACLED

# %%
import pandas as pd
import numpy as np
import json 
import ast

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 73.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.0 tokenizers-0.13.2 transformers-4.26.0

# %%
from transformers import pipeline

# %%
protest = pd.read_csv('ACLED_protests-riots_1-26.csv')
us_topic = pd.read_csv("us_topic.csv")

# %% [markdown]
# # Model

# %%
# !pip install sentencepiece
# import sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.9 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
topic = []
labels = ["mining", "climate", "water", "nuclear", "biodiversity", "oil", "waste"]

# %%
pd.set_option('display.max_columns', None)
protest.head(1)
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0  9790398   24       ANG3791              3791  20 January 2023  2023
#
#    time_precision event_type    sub_event_type               actor1  \
# 0               1   Protests  Peaceful protest  Protesters (Angola)
#
#              assoc_actor_1  inter1 actor2 assoc_actor_2  inter2  interaction  \
# 0  Street Traders (Angola)       6    NaN           NaN       0           60
#
#           region country  admin1    admin2  admin3 location  latitude  \
# 0  Middle Africa  Angola  Cunene  Cuanhama  Onjiva  Ondjiva  -17.0666
#
#    longitude  geo_precision               source source_scale  \
# 0    15.7333              1  Angola Press Agency     National
#
#                                                notes  fatalities   timestamp  \
# 0  On 20 January 2023, vendors demonstrated at Os...           0  1674487330
#
#   iso3
# 0  AGO

# %%
protest_subset = protest.loc[protest['country'].isin(["United States"]) & (protest['event_type'] == "Protests")]
# protest_subset = protest.loc[protest['country'] == 'Sweden'| protest['country'] == 'South Korea']
# protest_subset = protest.query('country == Sweden & country == South Korea')

# %%
us_topic = us_topic[['labels', 'scores']]

# %%
protest_subset
# Out:
#         data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 231     9798576  840      USA51390             51390  20 January 2023  2023
# 232     9798585  840      USA51399             51399  20 January 2023  2023
# 233     9798587  840      USA51401             51401  20 January 2023  2023
# 234     9798594  840      USA51408             51408  20 January 2023  2023
# 235     9798598  840      USA51412             51412  20 January 2023  2023
# ...         ...  ...           ...               ...              ...   ...
# 496161  7616930  840      USA23636             23636  01 January 2020  2020
# 496162  7617409  840      USA23414             23414  01 January 2020  2020
# 496163  7617578  840      USA23635             23635  01 January 2020  2020
# 496173  8265777  840      USA23488             23488  01 January 2020  2020
# 496174  8265778  840      USA23726             23726  01 January 2020  2020
#
#         time_precision event_type    sub_event_type  \
# 231                  1   Protests  Peaceful protest
# 232                  1   Protests  Peaceful protest
# 233                  1   Protests  Peaceful protest
# 234                  1   Protests  Peaceful protest
# 235                  1   Protests  Peaceful protest
# ...                ...        ...               ...
# 496161               1   Protests  Peaceful protest
# 496162               1   Protests  Peaceful protest
# 496163               1   Protests  Peaceful protest
# 496173               1   Protests  Peaceful protest
# 496174               1   Protests  Peaceful protest
#
#                             actor1  \
# 231     Protesters (United States)
# 232     Protesters (United States)
# 233     Protesters (United States)
# 234     Protesters (United States)
# 235     Protesters (United States)
# ...                            ...
# 496161  Protesters (United States)
# 496162  Protesters (United States)
# 496163  Protesters (United States)
# 496173  Protesters (United States)
# 496174  Protesters (United States)
#
#                                       assoc_actor_1  inter1 actor2  \
# 231                                             NaN       6    NaN
# 232                        Students (United States)       6    NaN
# 233                    Labour Group (United States)       6    NaN
# 234                                             NaN       6    NaN
# 235                                             NaN       6    NaN
# ...                                             ...     ...    ...
# 496161  Government of the United States (2017-2021)       6    NaN
# 496162                                          NaN       6    NaN
# 496163                      BLM: Black Lives Matter       6    NaN
# 496173                                          NaN       6    NaN
# 496174                                          NaN       6    NaN
#
#        assoc_actor_2  inter2  interaction         region        country  \
# 231              NaN       0           60  North America  United States
# 232              NaN       0           60  North America  United States
# 233              NaN       0           60  North America  United States
# 234              NaN       0           60  North America  United States
# 235              NaN       0           60  North America  United States
# ...              ...     ...          ...            ...            ...
# 496161           NaN       0           60  North America  United States
# 496162           NaN       0           60  North America  United States
# 496163           NaN       0           60  North America  United States
# 496173           NaN       0           60  North America  United States
# 496174           NaN       0           60  North America  United States
#
#                 admin1       admin2 admin3              location  latitude  \
# 231            Georgia       Fulton    NaN               Atlanta   33.7559
# 232       North Dakota     Burleigh    NaN              Bismarck   46.8088
# 233          Louisiana   Washington    NaN              Bogalusa   30.7910
# 234       Pennsylvania    Allegheny    NaN           Bridgeville   40.3562
# 235     North Carolina  Mecklenburg    NaN             Charlotte   35.2274
# ...                ...          ...    ...                   ...       ...
# 496161         Arizona     Maricopa    NaN               Phoenix   33.4492
# 496162        New York     New York    NaN  New York - Manhattan   40.7834
# 496163      California      Alameda    NaN               Oakland   37.8044
# 496173         Florida   Palm Beach    NaN       West Palm Beach   26.7097
# 496174        Oklahoma     Oklahoma    NaN         Oklahoma City   35.4657
#
#         longitude  geo_precision  \
# 231      -84.3898              1
# 232     -100.7825              1
# 233      -89.8487              1
# 234      -80.1101              1
# 235      -80.8431              1
# ...           ...            ...
# 496161  -112.0741              1
# 496162   -73.9663              1
# 496163  -122.2711              1
# 496173   -80.0642              1
# 496174   -97.5128              1
#
#                                                    source       source_scale  \
# 231      Atlanta Journal Constitution; Atlanta News First        Subnational
# 232                                   KFYR-TV; KXMC CBS13        Subnational
# 233                                 Louisiana Illuminator        Subnational
# 234                               Channel 11 (Pittsburgh)        Subnational
# 235                          Atlanta Journal Constitution           National
# ...                                                   ...                ...
# 496161                      Count Love; Channel 12 (Mesa)  Other-Subnational
# 496162                                    CBS2 (New York)        Subnational
# 496163                                          KTVU Fox2        Subnational
# 496173  CBS12 (West Palm Beach); Crowd Counting Consor...  Other-Subnational
# 496174                           Oklahoma City Free Press           National
#
#                                                     notes  fatalities  \
# 231     On 20 January 2023, demonstrators gathered at ...           0
# 232     On 20 January 2023, hundreds of people rallied...           0
# 233     On 20 January 2023, Maximus call center worker...           0
# 234     On 20 January 2023, an unreported number of pe...           0
# 235     On 20 January 2023, demonstrators gathered in ...           0
# ...                                                   ...         ...
# 496161  On 1 January 2020, a group of people gathered ...           0
# 496162  On 1 January 2020, protesters gathered at NYPD...           0
# 496163  On 1 January 2020, a group of people gathered ...           0
# 496173  On 1 January 2020, protesters assembled along ...           0
# 496174  On 1 January 2020, protesters against Oklahoma...           0
#
#          timestamp iso3
# 231     1674584447  USA
# 232     1674584447  USA
# 233     1674584448  USA
# 234     1674584448  USA
# 235     1674584448  USA
# ...            ...  ...
# 496161  1612546518  USA
# 496162  1612546519  USA
# 496163  1612546519  USA
# 496173  1624483201  USA
# 496174  1624483201  USA
#
# [47050 rows x 31 columns]

# %%
import ast

us_topic['labels'] = us_topic['labels'].apply(lambda x: ast.literal_eval(x))
us_topic['scores'] = us_topic['scores'].apply(lambda x: ast.literal_eval(x))

# %%
us_topic
# Out:
#                                                   labels  \
# 0      [environment, race, human rights, workers righ...
# 1      [environment, race, human rights, LGBT, educat...
# 2      [workers rights, race, human rights, environme...
# 3      [health care, human rights, race, environment,...
# 4      [environment, race, human rights, workers righ...
# ...                                                  ...
# 47045  [environment, race, human rights, education, L...
# 47046  [race, environment, human rights, workers righ...
# 47047  [race, human rights, environment, education, w...
# 47048  [environment, race, human rights, LGBT, worker...
# 47049  [human rights, environment, race, workers righ...
#
#                                                   scores
# 0      [0.5511378049850464, 0.14793211221694946, 0.10...
# 1      [0.26701101660728455, 0.22268570959568024, 0.1...
# 2      [0.7761732339859009, 0.07395867258310318, 0.05...
# 3      [0.7006431818008423, 0.09934472292661667, 0.07...
# 4      [0.4066563844680786, 0.2916755676269531, 0.103...
# ...                                                  ...
# 47045  [0.29784291982650757, 0.22314944863319397, 0.1...
# 47046  [0.8296008706092834, 0.06485608965158463, 0.04...
# 47047  [0.5182317495346069, 0.13798002898693085, 0.12...
# 47048  [0.2888628840446472, 0.2711745500564575, 0.139...
# 47049  [0.4024437665939331, 0.2801186442375183, 0.113...
#
# [47050 rows x 2 columns]

# %%
# protest_topic['labels'][0]

# %%
# # use zip function to match the scores with the corresponding labels
# protest_topic['label_score'] = [dict(zip(labels, scores)) for labels, scores in zip(protest_topic.labels, protest_topic.scores)]

# # Use the pandas DataFrame.from_records() function to convert the list of dictionaries into a dataframe
# result = pd.DataFrame.from_records(protest_topic['label_score'])

us_topic["label_scores"] = us_topic.apply(lambda x: dict(zip(x["labels"], x["scores"])), axis=1)
us_topic = pd.json_normalize(us_topic['label_scores'].tolist())

# %%
us_topic
# Out:
#        environment      race  human rights  workers rights  education  \
# 0         0.551138  0.147932      0.103969        0.065066   0.063056
# 1         0.267011  0.222686      0.196256        0.058765   0.089072
# 2         0.056274  0.073959      0.057083        0.776173   0.010090
# 3         0.045111  0.078714      0.099345        0.021879   0.020015
# 4         0.406656  0.291676      0.103326        0.074727   0.049454
# ...            ...       ...           ...             ...        ...
# 47045     0.297843  0.223149      0.161878        0.087023   0.096003
# 47046     0.064856  0.829601      0.048875        0.026602   0.011335
# 47047     0.125470  0.518232      0.137980        0.055493   0.073013
# 47048     0.288863  0.271175      0.139584        0.080217   0.066618
# 47049     0.280119  0.113970      0.402444        0.069358   0.060566
#
#        health care      LGBT
# 0         0.044354  0.024485
# 1         0.073042  0.093168
# 2         0.008232  0.018189
# 3         0.700643  0.034293
# 4         0.044578  0.029583
# ...            ...       ...
# 47045     0.043748  0.090356
# 47046     0.010778  0.007953
# 47047     0.043890  0.045922
# 47048     0.059636  0.093907
# 47049     0.037645  0.035900
#
# [47050 rows x 7 columns]

# %%
# protest_subset = protest_subset[:24506]
protest_subset = protest_subset.reset_index(drop=True)
us_topic = us_topic.reset_index(drop=True)

# %%
environment_us = pd.concat([protest_subset, us_topic], axis = 1)
environment_us
# Out:
#        data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0      9798576  840      USA51390             51390  20 January 2023  2023
# 1      9798585  840      USA51399             51399  20 January 2023  2023
# 2      9798587  840      USA51401             51401  20 January 2023  2023
# 3      9798594  840      USA51408             51408  20 January 2023  2023
# 4      9798598  840      USA51412             51412  20 January 2023  2023
# ...        ...  ...           ...               ...              ...   ...
# 47045  7616930  840      USA23636             23636  01 January 2020  2020
# 47046  7617409  840      USA23414             23414  01 January 2020  2020
# 47047  7617578  840      USA23635             23635  01 January 2020  2020
# 47048  8265777  840      USA23488             23488  01 January 2020  2020
# 47049  8265778  840      USA23726             23726  01 January 2020  2020
#
#        time_precision event_type    sub_event_type  \
# 0                   1   Protests  Peaceful protest
# 1                   1   Protests  Peaceful protest
# 2                   1   Protests  Peaceful protest
# 3                   1   Protests  Peaceful protest
# 4                   1   Protests  Peaceful protest
# ...               ...        ...               ...
# 47045               1   Protests  Peaceful protest
# 47046               1   Protests  Peaceful protest
# 47047               1   Protests  Peaceful protest
# 47048               1   Protests  Peaceful protest
# 47049               1   Protests  Peaceful protest
#
#                            actor1  \
# 0      Protesters (United States)
# 1      Protesters (United States)
# 2      Protesters (United States)
# 3      Protesters (United States)
# 4      Protesters (United States)
# ...                           ...
# 47045  Protesters (United States)
# 47046  Protesters (United States)
# 47047  Protesters (United States)
# 47048  Protesters (United States)
# 47049  Protesters (United States)
#
#                                      assoc_actor_1  inter1 actor2  \
# 0                                              NaN       6    NaN
# 1                         Students (United States)       6    NaN
# 2                     Labour Group (United States)       6    NaN
# 3                                              NaN       6    NaN
# 4                                              NaN       6    NaN
# ...                                            ...     ...    ...
# 47045  Government of the United States (2017-2021)       6    NaN
# 47046                                          NaN       6    NaN
# 47047                      BLM: Black Lives Matter       6    NaN
# 47048                                          NaN       6    NaN
# 47049                                          NaN       6    NaN
#
#       assoc_actor_2  inter2  interaction         region        country  \
# 0               NaN       0           60  North America  United States
# 1               NaN       0           60  North America  United States
# 2               NaN       0           60  North America  United States
# 3               NaN       0           60  North America  United States
# 4               NaN       0           60  North America  United States
# ...             ...     ...          ...            ...            ...
# 47045           NaN       0           60  North America  United States
# 47046           NaN       0           60  North America  United States
# 47047           NaN       0           60  North America  United States
# 47048           NaN       0           60  North America  United States
# 47049           NaN       0           60  North America  United States
#
#                admin1       admin2 admin3              location  latitude  \
# 0             Georgia       Fulton    NaN               Atlanta   33.7559
# 1        North Dakota     Burleigh    NaN              Bismarck   46.8088
# 2           Louisiana   Washington    NaN              Bogalusa   30.7910
# 3        Pennsylvania    Allegheny    NaN           Bridgeville   40.3562
# 4      North Carolina  Mecklenburg    NaN             Charlotte   35.2274
# ...               ...          ...    ...                   ...       ...
# 47045         Arizona     Maricopa    NaN               Phoenix   33.4492
# 47046        New York     New York    NaN  New York - Manhattan   40.7834
# 47047      California      Alameda    NaN               Oakland   37.8044
# 47048         Florida   Palm Beach    NaN       West Palm Beach   26.7097
# 47049        Oklahoma     Oklahoma    NaN         Oklahoma City   35.4657
#
#        longitude  geo_precision  \
# 0       -84.3898              1
# 1      -100.7825              1
# 2       -89.8487              1
# 3       -80.1101              1
# 4       -80.8431              1
# ...          ...            ...
# 47045  -112.0741              1
# 47046   -73.9663              1
# 47047  -122.2711              1
# 47048   -80.0642              1
# 47049   -97.5128              1
#
#                                                   source       source_scale  \
# 0       Atlanta Journal Constitution; Atlanta News First        Subnational
# 1                                    KFYR-TV; KXMC CBS13        Subnational
# 2                                  Louisiana Illuminator        Subnational
# 3                                Channel 11 (Pittsburgh)        Subnational
# 4                           Atlanta Journal Constitution           National
# ...                                                  ...                ...
# 47045                      Count Love; Channel 12 (Mesa)  Other-Subnational
# 47046                                    CBS2 (New York)        Subnational
# 47047                                          KTVU Fox2        Subnational
# 47048  CBS12 (West Palm Beach); Crowd Counting Consor...  Other-Subnational
# 47049                           Oklahoma City Free Press           National
#
#                                                    notes  fatalities  \
# 0      On 20 January 2023, demonstrators gathered at ...           0
# 1      On 20 January 2023, hundreds of people rallied...           0
# 2      On 20 January 2023, Maximus call center worker...           0
# 3      On 20 January 2023, an unreported number of pe...           0
# 4      On 20 January 2023, demonstrators gathered in ...           0
# ...                                                  ...         ...
# 47045  On 1 January 2020, a group of people gathered ...           0
# 47046  On 1 January 2020, protesters gathered at NYPD...           0
# 47047  On 1 January 2020, a group of people gathered ...           0
# 47048  On 1 January 2020, protesters assembled along ...           0
# 47049  On 1 January 2020, protesters against Oklahoma...           0
#
#         timestamp iso3  environment      race  human rights  workers rights  \
# 0      1674584447  USA     0.551138  0.147932      0.103969        0.065066
# 1      1674584447  USA     0.267011  0.222686      0.196256        0.058765
# 2      1674584448  USA     0.056274  0.073959      0.057083        0.776173
# 3      1674584448  USA     0.045111  0.078714      0.099345        0.021879
# 4      1674584448  USA     0.406656  0.291676      0.103326        0.074727
# ...           ...  ...          ...       ...           ...             ...
# 47045  1612546518  USA     0.297843  0.223149      0.161878        0.087023
# 47046  1612546519  USA     0.064856  0.829601      0.048875        0.026602
# 47047  1612546519  USA     0.125470  0.518232      0.137980        0.055493
# 47048  1624483201  USA     0.288863  0.271175      0.139584        0.080217
# 47049  1624483201  USA     0.280119  0.113970      0.402444        0.069358
#
#        education  health care      LGBT
# 0       0.063056     0.044354  0.024485
# 1       0.089072     0.073042  0.093168
# 2       0.010090     0.008232  0.018189
# 3       0.020015     0.700643  0.034293
# 4       0.049454     0.044578  0.029583
# ...          ...          ...       ...
# 47045   0.096003     0.043748  0.090356
# 47046   0.011335     0.010778  0.007953
# 47047   0.073013     0.043890  0.045922
# 47048   0.066618     0.059636  0.093907
# 47049   0.060566     0.037645  0.035900
#
# [47050 rows x 38 columns]

# %%
environment_us.to_csv("protest_topic.csv")

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ACLED

# %%
env_protest_us = pd.read_csv("protest_topic.csv")

# %%
env_protest_us

# %%
topic = []
labels = ["mining", "climate", "water", "nuclear", "biodiversity", "oil", "waste"]

# %%
env_protest_us = environment_us[environment_us['environment'] > 0.4]

# %%
environment_us['environment'].describe()
# Out:
# count    24506.000000
# mean         0.088110
# std          0.171282
# min          0.000572
# 25%          0.008550
# 50%          0.033949
# 75%          0.089328
# max          0.991540
# Name: environment, dtype: float64

# %%
env_protest_us
# Out:
#        data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0      9798576  840      USA51390             51390  20 January 2023  2023
# 4      9798598  840      USA51412             51412  20 January 2023  2023
# 7      9798635  840      USA51449             51449  20 January 2023  2023
# 10     9798661  840      USA51475             51475  20 January 2023  2023
# 11     9798664  840      USA51478             51478  20 January 2023  2023
# ...        ...  ...           ...               ...              ...   ...
# 46989  7617630  840      USA23407             23407  04 January 2020  2020
# 47027  7616917  840      USA23618             23618  03 January 2020  2020
# 47028  7616991  840      USA23727             23727  03 January 2020  2020
# 47031  7617620  840      USA23418             23418  03 January 2020  2020
# 47039  7617453  840      USA23789             23789  02 January 2020  2020
#
#        time_precision event_type             sub_event_type  \
# 0                   1   Protests           Peaceful protest
# 4                   1   Protests           Peaceful protest
# 7                   1   Protests           Peaceful protest
# 10                  1   Protests           Peaceful protest
# 11                  1   Protests           Peaceful protest
# ...               ...        ...                        ...
# 46989               1   Protests           Peaceful protest
# 47027               1   Protests  Protest with intervention
# 47028               1   Protests           Peaceful protest
# 47031               1   Protests           Peaceful protest
# 47039               1   Protests           Peaceful protest
#
#                            actor1  \
# 0      Protesters (United States)
# 4      Protesters (United States)
# 7      Protesters (United States)
# 10     Protesters (United States)
# 11     Protesters (United States)
# ...                           ...
# 46989  Protesters (United States)
# 47027  Protesters (United States)
# 47028  Protesters (United States)
# 47031  Protesters (United States)
# 47039  Protesters (United States)
#
#                                            assoc_actor_1  inter1  \
# 0                                                    NaN       6
# 4                                                    NaN       6
# 7      Native American Group (United States); Student...       6
# 10                                                   NaN       6
# 11                                                   NaN       6
# ...                                                  ...     ...
# 46989                                                NaN       6
# 47027                                                NaN       6
# 47028                                                NaN       6
# 47031                           Students (United States)       6
# 47039                                                NaN       6
#
#                                                actor2 assoc_actor_2  inter2  \
# 0                                                 NaN           NaN       0
# 4                                                 NaN           NaN       0
# 7                                                 NaN           NaN       0
# 10                                                NaN           NaN       0
# 11                                                NaN           NaN       0
# ...                                               ...           ...     ...
# 46989                                             NaN           NaN       0
# 47027  Police Forces of the United States (2017-2021)           NaN       1
# 47028                                             NaN           NaN       0
# 47031                                             NaN           NaN       0
# 47039                                             NaN           NaN       0
#
#        interaction         region        country          admin1  \
# 0               60  North America  United States         Georgia
# 4               60  North America  United States  North Carolina
# 7               60  North America  United States         Montana
# 10              60  North America  United States        Nebraska
# 11              60  North America  United States      California
# ...            ...            ...            ...             ...
# 46989           60  North America  United States      New Jersey
# 47027           16  North America  United States   Massachusetts
# 47028           60  North America  United States           Texas
# 47031           60  North America  United States         Vermont
# 47039           60  North America  United States        Colorado
#
#                 admin2 admin3        location  latitude  longitude  \
# 0               Fulton    NaN         Atlanta   33.7559   -84.3898
# 4          Mecklenburg    NaN       Charlotte   35.2274   -80.8431
# 7      Lewis and Clark    NaN          Helena   46.5893  -112.0391
# 10           Lancaster    NaN         Lincoln   40.8080   -96.6997
# 11         Los Angeles    NaN     Los Angeles   34.0433  -118.2495
# ...                ...    ...             ...       ...        ...
# 46989        Middlesex    NaN      Woodbridge   40.5576   -74.2846
# 47027        Worcester    NaN         Harvard   42.5001   -71.5828
# 47028       Williamson    NaN      Georgetown   30.6327   -97.6772
# 47031       Washington    NaN      Montpelier   44.2626   -72.5806
# 47039             Mesa    NaN  Grand Junction   39.0639  -108.5506
#
#        geo_precision                                             source  \
# 0                  1   Atlanta Journal Constitution; Atlanta News First
# 4                  1                       Atlanta Journal Constitution
# 7                  1                            Bozeman Daily Chronicle
# 10                 1                       Atlanta Journal Constitution
# 11                 1                       Atlanta Journal Constitution
# ...              ...                                                ...
# 46989              1                                News12 (New Jersey)
# 47027              1  WBZ Channel 4; Telegram & Gazette; WHDH Channe...
# 47028              1              Austin American-Statesman; Count Love
# 47031              1                                 NBC5 (Plattsburgh)
# 47039              1                    Daily Sentinel (Grand Junction)
#
#                source_scale  \
# 0               Subnational
# 4                  National
# 7               Subnational
# 10                 National
# 11                 National
# ...                     ...
# 46989           Subnational
# 47027  Subnational-National
# 47028     Other-Subnational
# 47031           Subnational
# 47039           Subnational
#
#                                                    notes  fatalities  \
# 0      On 20 January 2023, demonstrators gathered at ...           0
# 4      On 20 January 2023, demonstrators gathered in ...           0
# 7      On 20 January 2023, nearly 300 environmental a...           0
# 10     On 20 January 2023, demonstrators gathered in ...           0
# 11     On 20 January 2023, demonstrators gathered in ...           0
# ...                                                  ...         ...
# 46989  On 4 January 2020, more than 50 people gathere...           0
# 47027  On 3 January 2020, 4 climate change activists ...           0
# 47028  On 3 January 2020, local residents protested i...           0
# 47031  On 3 January 2020, more than 40 students gathe...           0
# 47039  On 2 January 2020, several dozen people gather...           0
#
#         timestamp iso3  environment      race  human rights  workers rights  \
# 0      1674584447  USA     0.551138  0.147932      0.103969        0.065066
# 4      1674584448  USA     0.406656  0.291676      0.103326        0.074727
# 7      1674584448  USA     0.835429  0.079229      0.026319        0.012776
# 10     1674584448  USA     0.419230  0.271123      0.113753        0.073506
# 11     1674584448  USA     0.420665  0.259557      0.110738        0.079912
# ...           ...  ...          ...       ...           ...             ...
# 46989  1612546519  USA     0.478845  0.210175      0.112667        0.078404
# 47027  1612546518  USA     0.877534  0.030912      0.032489        0.025096
# 47028  1612546518  USA     0.506298  0.151576      0.085632        0.107967
# 47031  1612546519  USA     0.899100  0.039389      0.013956        0.012175
# 47039  1612546519  USA     0.458001  0.178738      0.139461        0.068398
#
#        education  health care      LGBT
# 0       0.063056     0.044354  0.024485
# 4       0.049454     0.044578  0.029583
# 7       0.017352     0.011652  0.017243
# 10      0.046291     0.045640  0.030458
# 11      0.049289     0.044818  0.035021
# ...          ...          ...       ...
# 46989   0.037797     0.028966  0.053146
# 47027   0.011899     0.011096  0.010975
# 47028   0.037561     0.042501  0.068464
# 47031   0.011317     0.006313  0.017750
# 47039   0.063266     0.022245  0.069891
#
# [2311 rows x 38 columns]

# %%
# lgbt_protest_us = environment_us[environment_us['LGBT'] > 0.75]

# %%
topic
# Out:
# []

# %%
for i in range(len(env_protest_us)):
  result = classifier(env_protest_us["notes"].tolist()[i], labels, multi_label=False)
  topic.append(result)

# %%
env_protest_topic = pd.DataFrame(topic)

# %%
env_protest_topic
# Out:
#                                                sequence  \
# 0     On 20 January 2023, demonstrators gathered at ...
# 1     On 20 January 2023, demonstrators gathered in ...
# 2     On 20 January 2023, nearly 300 environmental a...
# 3     On 20 January 2023, demonstrators gathered in ...
# 4     On 20 January 2023, demonstrators gathered in ...
# ...                                                 ...
# 2306  On 4 January 2020, more than 50 people gathere...
# 2307  On 3 January 2020, 4 climate change activists ...
# 2308  On 3 January 2020, local residents protested i...
# 2309  On 3 January 2020, more than 40 students gathe...
# 2310  On 2 January 2020, several dozen people gather...
#
#                                                  labels  \
# 0     [climate, biodiversity, water, oil, mining, nu...
# 1     [climate, biodiversity, water, oil, mining, nu...
# 2     [climate, water, biodiversity, waste, nuclear,...
# 3     [climate, biodiversity, water, oil, mining, nu...
# 4     [biodiversity, climate, water, oil, mining, nu...
# ...                                                 ...
# 2306  [water, biodiversity, waste, oil, climate, min...
# 2307  [climate, biodiversity, oil, water, waste, min...
# 2308  [waste, biodiversity, water, climate, oil, min...
# 2309  [climate, water, biodiversity, oil, waste, nuc...
# 2310  [biodiversity, water, climate, waste, oil, nuc...
#
#                                                  scores
# 0     [0.31555208563804626, 0.19003430008888245, 0.1...
# 1     [0.2963591516017914, 0.2811942994594574, 0.156...
# 2     [0.9387708902359009, 0.02011682651937008, 0.01...
# 3     [0.26561930775642395, 0.2604045867919922, 0.18...
# 4     [0.32161498069763184, 0.2189861685037613, 0.17...
# ...                                                 ...
# 2306  [0.6715523600578308, 0.11532134562730789, 0.07...
# 2307  [0.9754398465156555, 0.005822023376822472, 0.0...
# 2308  [0.2412378191947937, 0.18861043453216553, 0.16...
# 2309  [0.9691158533096313, 0.009419219568371773, 0.0...
# 2310  [0.2598259747028351, 0.24201010167598724, 0.18...
#
# [2311 rows x 3 columns]

# %%
env_protest_topic = env_protest_topic[['labels', 'scores']]

# %%
import ast

env_protest_topic['labels'] = env_protest_topic['labels'].apply(lambda x: ast.literal_eval(x))
env_protest_topic['scores'] = env_protest_topic['scores'].apply(lambda x: ast.literal_eval(x))

# %%
env_protest_topic["label_scores"] = env_protest_topic.apply(lambda x: dict(zip(x["labels"], x["scores"])), axis=1)
env_protest_topic = pd.json_normalize(env_protest_topic['label_scores'].tolist())

# %%
env_protest_topic
# Out:
#        climate  biodiversity     water       oil    mining   nuclear     waste
# 0     0.315552      0.190034  0.183163  0.142651  0.072023  0.058585  0.037992
# 1     0.296359      0.281194  0.156399  0.112961  0.072971  0.048894  0.031222
# 2     0.938771      0.016395  0.020117  0.005709  0.003544  0.006217  0.009247
# 3     0.265619      0.260405  0.182422  0.123634  0.080406  0.054059  0.033454
# 4     0.218986      0.321615  0.173976  0.129390  0.073598  0.049632  0.032802
# ...        ...           ...       ...       ...       ...       ...       ...
# 2306  0.041410      0.115321  0.671552  0.052186  0.020789  0.020015  0.078727
# 2307  0.975440      0.005822  0.004403  0.004418  0.003333  0.002988  0.003597
# 2308  0.153716      0.188610  0.169595  0.094761  0.078829  0.073250  0.241238
# 2309  0.969116      0.005797  0.009419  0.005683  0.002900  0.003277  0.003808
# 2310  0.181218      0.259826  0.242010  0.076764  0.056495  0.076394  0.107294
#
# [2311 rows x 7 columns]

# %%
env_protest_us = env_protest_us.reset_index(drop=True)
env_protest_topic = env_protest_topic.reset_index(drop=True)

# %%
env_protest_topic_us = pd.concat([env_protest_us, env_protest_topic], axis = 1)
env_protest_topic_us
# Out:
#       data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0     9798576  840      USA51390             51390  20 January 2023  2023
# 1     9798598  840      USA51412             51412  20 January 2023  2023
# 2     9798635  840      USA51449             51449  20 January 2023  2023
# 3     9798661  840      USA51475             51475  20 January 2023  2023
# 4     9798664  840      USA51478             51478  20 January 2023  2023
# ...       ...  ...           ...               ...              ...   ...
# 2306  7617630  840      USA23407             23407  04 January 2020  2020
# 2307  7616917  840      USA23618             23618  03 January 2020  2020
# 2308  7616991  840      USA23727             23727  03 January 2020  2020
# 2309  7617620  840      USA23418             23418  03 January 2020  2020
# 2310  7617453  840      USA23789             23789  02 January 2020  2020
#
#       time_precision event_type             sub_event_type  \
# 0                  1   Protests           Peaceful protest
# 1                  1   Protests           Peaceful protest
# 2                  1   Protests           Peaceful protest
# 3                  1   Protests           Peaceful protest
# 4                  1   Protests           Peaceful protest
# ...              ...        ...                        ...
# 2306               1   Protests           Peaceful protest
# 2307               1   Protests  Protest with intervention
# 2308               1   Protests           Peaceful protest
# 2309               1   Protests           Peaceful protest
# 2310               1   Protests           Peaceful protest
#
#                           actor1  \
# 0     Protesters (United States)
# 1     Protesters (United States)
# 2     Protesters (United States)
# 3     Protesters (United States)
# 4     Protesters (United States)
# ...                          ...
# 2306  Protesters (United States)
# 2307  Protesters (United States)
# 2308  Protesters (United States)
# 2309  Protesters (United States)
# 2310  Protesters (United States)
#
#                                           assoc_actor_1  inter1  \
# 0                                                   NaN       6
# 1                                                   NaN       6
# 2     Native American Group (United States); Student...       6
# 3                                                   NaN       6
# 4                                                   NaN       6
# ...                                                 ...     ...
# 2306                                                NaN       6
# 2307                                                NaN       6
# 2308                                                NaN       6
# 2309                           Students (United States)       6
# 2310                                                NaN       6
#
#                                               actor2 assoc_actor_2  inter2  \
# 0                                                NaN           NaN       0
# 1                                                NaN           NaN       0
# 2                                                NaN           NaN       0
# 3                                                NaN           NaN       0
# 4                                                NaN           NaN       0
# ...                                              ...           ...     ...
# 2306                                             NaN           NaN       0
# 2307  Police Forces of the United States (2017-2021)           NaN       1
# 2308                                             NaN           NaN       0
# 2309                                             NaN           NaN       0
# 2310                                             NaN           NaN       0
#
#       interaction         region        country          admin1  \
# 0              60  North America  United States         Georgia
# 1              60  North America  United States  North Carolina
# 2              60  North America  United States         Montana
# 3              60  North America  United States        Nebraska
# 4              60  North America  United States      California
# ...           ...            ...            ...             ...
# 2306           60  North America  United States      New Jersey
# 2307           16  North America  United States   Massachusetts
# 2308           60  North America  United States           Texas
# 2309           60  North America  United States         Vermont
# 2310           60  North America  United States        Colorado
#
#                admin2 admin3        location  latitude  longitude  \
# 0              Fulton    NaN         Atlanta   33.7559   -84.3898
# 1         Mecklenburg    NaN       Charlotte   35.2274   -80.8431
# 2     Lewis and Clark    NaN          Helena   46.5893  -112.0391
# 3           Lancaster    NaN         Lincoln   40.8080   -96.6997
# 4         Los Angeles    NaN     Los Angeles   34.0433  -118.2495
# ...               ...    ...             ...       ...        ...
# 2306        Middlesex    NaN      Woodbridge   40.5576   -74.2846
# 2307        Worcester    NaN         Harvard   42.5001   -71.5828
# 2308       Williamson    NaN      Georgetown   30.6327   -97.6772
# 2309       Washington    NaN      Montpelier   44.2626   -72.5806
# 2310             Mesa    NaN  Grand Junction   39.0639  -108.5506
#
#       geo_precision                                             source  \
# 0                 1   Atlanta Journal Constitution; Atlanta News First
# 1                 1                       Atlanta Journal Constitution
# 2                 1                            Bozeman Daily Chronicle
# 3                 1                       Atlanta Journal Constitution
# 4                 1                       Atlanta Journal Constitution
# ...             ...                                                ...
# 2306              1                                News12 (New Jersey)
# 2307              1  WBZ Channel 4; Telegram & Gazette; WHDH Channe...
# 2308              1              Austin American-Statesman; Count Love
# 2309              1                                 NBC5 (Plattsburgh)
# 2310              1                    Daily Sentinel (Grand Junction)
#
#               source_scale                                              notes  \
# 0              Subnational  On 20 January 2023, demonstrators gathered at ...
# 1                 National  On 20 January 2023, demonstrators gathered in ...
# 2              Subnational  On 20 January 2023, nearly 300 environmental a...
# 3                 National  On 20 January 2023, demonstrators gathered in ...
# 4                 National  On 20 January 2023, demonstrators gathered in ...
# ...                    ...                                                ...
# 2306           Subnational  On 4 January 2020, more than 50 people gathere...
# 2307  Subnational-National  On 3 January 2020, 4 climate change activists ...
# 2308     Other-Subnational  On 3 January 2020, local residents protested i...
# 2309           Subnational  On 3 January 2020, more than 40 students gathe...
# 2310           Subnational  On 2 January 2020, several dozen people gather...
#
#       fatalities   timestamp iso3  environment      race  human rights  \
# 0              0  1674584447  USA     0.551138  0.147932      0.103969
# 1              0  1674584448  USA     0.406656  0.291676      0.103326
# 2              0  1674584448  USA     0.835429  0.079229      0.026319
# 3              0  1674584448  USA     0.419230  0.271123      0.113753
# 4              0  1674584448  USA     0.420665  0.259557      0.110738
# ...          ...         ...  ...          ...       ...           ...
# 2306           0  1612546519  USA     0.478845  0.210175      0.112667
# 2307           0  1612546518  USA     0.877534  0.030912      0.032489
# 2308           0  1612546518  USA     0.506298  0.151576      0.085632
# 2309           0  1612546519  USA     0.899100  0.039389      0.013956
# 2310           0  1612546519  USA     0.458001  0.178738      0.139461
#
#       workers rights  education  health care      LGBT   climate  \
# 0           0.065066   0.063056     0.044354  0.024485  0.315552
# 1           0.074727   0.049454     0.044578  0.029583  0.296359
# 2           0.012776   0.017352     0.011652  0.017243  0.938771
# 3           0.073506   0.046291     0.045640  0.030458  0.265619
# 4           0.079912   0.049289     0.044818  0.035021  0.218986
# ...              ...        ...          ...       ...       ...
# 2306        0.078404   0.037797     0.028966  0.053146  0.041410
# 2307        0.025096   0.011899     0.011096  0.010975  0.975440
# 2308        0.107967   0.037561     0.042501  0.068464  0.153716
# 2309        0.012175   0.011317     0.006313  0.017750  0.969116
# 2310        0.068398   0.063266     0.022245  0.069891  0.181218
#
#       biodiversity     water       oil    mining   nuclear     waste
# 0         0.190034  0.183163  0.142651  0.072023  0.058585  0.037992
# 1         0.281194  0.156399  0.112961  0.072971  0.048894  0.031222
# 2         0.016395  0.020117  0.005709  0.003544  0.006217  0.009247
# 3         0.260405  0.182422  0.123634  0.080406  0.054059  0.033454
# 4         0.321615  0.173976  0.129390  0.073598  0.049632  0.032802
# ...            ...       ...       ...       ...       ...       ...
# 2306      0.115321  0.671552  0.052186  0.020789  0.020015  0.078727
# 2307      0.005822  0.004403  0.004418  0.003333  0.002988  0.003597
# 2308      0.188610  0.169595  0.094761  0.078829  0.073250  0.241238
# 2309      0.005797  0.009419  0.005683  0.002900  0.003277  0.003808
# 2310      0.259826  0.242010  0.076764  0.056495  0.076394  0.107294
#
# [2311 rows x 45 columns]

# %%
env_protest_topic_us['topic_env'] = ''
columns = ["mining", "climate", "water", "nuclear", "biodiversity", "oil", "waste"]

for i, row in env_protest_topic_us.iterrows():
    largest_value = 0
    largest_column = ''
    for col in columns:
        if row[col] > largest_value:
            largest_value = row[col]
            largest_column = col
    env_protest_topic_us.at[i, 'topic_env'] = largest_column

# %%
env_protest_topic_us
# Out:
#       data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0     9798635  840      USA51449             51449  20 January 2023  2023
# 1     9798565  840      USA51379             51379  19 January 2023  2023
# 2     9798589  840      USA51403             51403  18 January 2023  2023
# 3     9798563  840      USA51377             51377  17 January 2023  2023
# 4     9798588  840      USA51402             51402  17 January 2023  2023
# ...       ...  ...           ...               ...              ...   ...
# 1203  7617445  840      USA23352             23352  06 January 2020  2020
# 1204  7616764  840      USA23330             23330  04 January 2020  2020
# 1205  7616917  840      USA23618             23618  03 January 2020  2020
# 1206  7616991  840      USA23727             23727  03 January 2020  2020
# 1207  7617620  840      USA23418             23418  03 January 2020  2020
#
#       time_precision event_type             sub_event_type  \
# 0                  1   Protests           Peaceful protest
# 1                  1   Protests           Peaceful protest
# 2                  1   Protests  Protest with intervention
# 3                  1   Protests           Peaceful protest
# 4                  1   Protests  Protest with intervention
# ...              ...        ...                        ...
# 1203               1   Protests           Peaceful protest
# 1204               1   Protests           Peaceful protest
# 1205               1   Protests  Protest with intervention
# 1206               1   Protests           Peaceful protest
# 1207               1   Protests           Peaceful protest
#
#                           actor1  \
# 0     Protesters (United States)
# 1     Protesters (United States)
# 2     Protesters (United States)
# 3     Protesters (United States)
# 4     Protesters (United States)
# ...                          ...
# 1203  Protesters (United States)
# 1204  Protesters (United States)
# 1205  Protesters (United States)
# 1206  Protesters (United States)
# 1207  Protesters (United States)
#
#                                           assoc_actor_1  inter1  \
# 0     Native American Group (United States); Student...       6
# 1                                                   NaN       6
# 2                                  Extinction Rebellion       6
# 3     LIUNA: Laborers' International Union of North ...       6
# 4                                  Extinction Rebellion       6
# ...                                                 ...     ...
# 1203                                                NaN       6
# 1204                                                NaN       6
# 1205                                                NaN       6
# 1206                                                NaN       6
# 1207                           Students (United States)       6
#
#                                               actor2 assoc_actor_2  inter2  \
# 0                                                NaN           NaN       0
# 1                                                NaN           NaN       0
# 2         Police Forces of the United States (2021-)           NaN       1
# 3                                                NaN           NaN       0
# 4         Police Forces of the United States (2021-)           NaN       1
# ...                                              ...           ...     ...
# 1203                                             NaN           NaN       0
# 1204                                             NaN           NaN       0
# 1205  Police Forces of the United States (2017-2021)           NaN       1
# 1206                                             NaN           NaN       0
# 1207                                             NaN           NaN       0
#
#       interaction         region        country         admin1  \
# 0              60  North America  United States        Montana
# 1              60  North America  United States       New York
# 2              16  North America  United States  Massachusetts
# 3              60  North America  United States       New York
# 4              16  North America  United States  Massachusetts
# ...           ...            ...            ...            ...
# 1203           60  North America  United States       Michigan
# 1204           60  North America  United States      Wisconsin
# 1205           16  North America  United States  Massachusetts
# 1206           60  North America  United States          Texas
# 1207           60  North America  United States        Vermont
#
#                admin2 admin3    location  latitude  longitude  geo_precision  \
# 0     Lewis and Clark    NaN      Helena   46.5893  -112.0391              1
# 1              Albany    NaN      Albany   42.6504   -73.7591              1
# 2             Suffolk    NaN      Boston   42.3591   -71.0639              1
# 3              Albany    NaN      Albany   42.6504   -73.7591              1
# 4             Suffolk    NaN      Boston   42.3591   -71.0639              1
# ...               ...    ...         ...       ...        ...            ...
# 1203        Washtenaw    NaN   Ann Arbor   42.2800   -83.7458              1
# 1204        Outagamie    NaN     Seymour   44.5086   -88.3283              1
# 1205        Worcester    NaN     Harvard   42.5001   -71.5828              1
# 1206       Williamson    NaN  Georgetown   30.6327   -97.6772              1
# 1207       Washington    NaN  Montpelier   44.2626   -72.5806              1
#
#                                                  source          source_scale  \
# 0                               Bozeman Daily Chronicle           Subnational
# 1                                       WTEN Channel 10           Subnational
# 2                    Extinction Rebellion Massachusetts                 Other
# 3                                          Katal Center                 Other
# 4                                Boston Globe; CBS News  Subnational-National
# ...                                                 ...                   ...
# 1203                                         Daily Item              National
# 1204                  WEAU13; Crowd Counting Consortium     Other-Subnational
# 1205  WBZ Channel 4; Telegram & Gazette; WHDH Channe...  Subnational-National
# 1206              Austin American-Statesman; Count Love     Other-Subnational
# 1207                                 NBC5 (Plattsburgh)           Subnational
#
#                                                   notes  fatalities  \
# 0     On 20 January 2023, nearly 300 environmental a...           0
# 1     On 19 January 2023, protesters rallied in Alba...           0
# 2     On 18 January 2023, protesters and members of ...           0
# 3     On 17 January 2023, protesters and members of ...           0
# 4     On 17 January 2023, protesters, local resident...           0
# ...                                                 ...         ...
# 1203  On 6 January 2020, about 10 members of the Fri...           0
# 1204  On 4 January 2020, more than 20 protesters gat...           0
# 1205  On 3 January 2020, 4 climate change activists ...           0
# 1206  On 3 January 2020, local residents protested i...           0
# 1207  On 3 January 2020, more than 40 students gathe...           0
#
#        timestamp iso3  human rights      race  environment  education  \
# 0     1674584448  USA      0.029607  0.024564     0.831526   0.092412
# 1     1674584447  USA      0.070917  0.055056     0.773200   0.027956
# 2     1674584448  USA      0.092118  0.313584     0.528267   0.010787
# 3     1674584447  USA      0.109145  0.083190     0.596708   0.025471
# 4     1674584448  USA      0.095939  0.302809     0.545421   0.011538
# ...          ...  ...           ...       ...          ...        ...
# 1203  1612546519  USA      0.077728  0.128826     0.631768   0.054361
# 1204  1612546518  USA      0.064934  0.033136     0.783883   0.020371
# 1205  1612546518  USA      0.096439  0.027745     0.699024   0.099134
# 1206  1612546518  USA      0.103098  0.114026     0.516532   0.079721
# 1207  1612546519  USA      0.028812  0.014483     0.846705   0.095504
#
#       workers rights  health care      LGBT   climate     waste     water  \
# 0           0.004226     0.012393  0.005272  0.862574  0.057721  0.022093
# 1           0.028266     0.014664  0.029942  0.524135  0.115151  0.015092
# 2           0.019550     0.006492  0.029203  0.432082  0.305195  0.068627
# 3           0.123022     0.016633  0.045830  0.735340  0.079401  0.050274
# 4           0.010738     0.006753  0.026802  0.360724  0.400326  0.052043
# ...              ...          ...       ...       ...       ...       ...
# 1203        0.036480     0.038920  0.031918  0.009926  0.054900  0.013985
# 1204        0.032733     0.039318  0.025626  0.229596  0.366443  0.315088
# 1205        0.054484     0.014816  0.008357  0.684306  0.227819  0.012845
# 1206        0.111747     0.033242  0.041634  0.228067  0.218980  0.044424
# 1207        0.003753     0.004473  0.006270  0.896160  0.032504  0.017579
#
#        nuclear       oil  biodiversity    mining     topic_env
# 0     0.020180  0.017361      0.011110  0.008962       climate
# 1     0.015471  0.303709      0.016306  0.010137       climate
# 2     0.040501  0.051359      0.082911  0.019325       climate
# 3     0.036925  0.037416      0.028486  0.032158       climate
# 4     0.031719  0.035850      0.102455  0.016882         waste
# ...        ...       ...           ...       ...           ...
# 1203  0.017799  0.011581      0.881510  0.010300  biodiversity
# 1204  0.016866  0.021033      0.021921  0.029053         waste
# 1205  0.010807  0.015944      0.026904  0.021377       climate
# 1206  0.044157  0.043220      0.387875  0.033277  biodiversity
# 1207  0.015387  0.015490      0.011600  0.011279       climate
#
# [1208 rows x 46 columns]

# %%
env_protest_topic_us.to_csv("env_protest_topic_us.csv")

# %%
sampled_df = protest_subset.sample(n=20, random_state=1)

# %%
len(sampled_df)
# Out:
# 20

# %%
for i in range(len(sampled_df)):
  result = classifier(sampled_df["notes"].tolist()[i], labels, multi_label=False)
  topic.append(result)

# %%
protest_topic = pd.DataFrame(topic)   
protest_topic

# %%
# # Use the pivot_table function to create separate columns for each label value
# result = protest_topic.scores.apply(pd.Series)
# result.columns = protest_topic.labels.iloc[0]

# %%
# new_df = protest_topic[["labels", "scores"]]
# new_df["label_scores"] = new_df.apply(lambda x: dict(zip(ast.literal_eval(x["labels"]), ast.literal_eval(x["scores"]))), axis=1)
# df_normalized = pd.json_normalize(new_df['label_scores'].tolist())

# %%
# use zip function to match the scores with the corresponding labels
protest_topic['label_score'] = [dict(zip(labels, scores)) for labels, scores in zip(protest_topic.labels, protest_topic.scores)]

# Use the pandas DataFrame.from_records() function to convert the list of dictionaries into a dataframe
result = pd.DataFrame.from_records(protest_topic['label_score'])

# %%
sampled_df = sampled_df.reset_index(drop=True)
result = result.reset_index(drop=True)

# %%
test = pd.concat([sampled_df, result], axis = 1)
test

# %%
test.to_csv("test_sample.csv")

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ACLED
